# %% [markdown]
# <a href="https://colab.research.google.com/github/Habeeb556/Spelling_Detection_and_Correction/blob/main/spell_checker_probabilistic_autocorrection_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re #regular expression modules
import string
from collections import Counter
import numpy as np

# %%
#tokenization
def read_corpus(filename):
  with open(filename, "r") as file:
    lines = file.readlines()
    words = [] 
    for line in lines:
      words += re.findall(r'\w+', line.lower()) # "w+" This expression matches the alphanumeric character in the string

  return words

# %%
words = read_corpus("./t8.shakespeare.txt") #read file
print(len(words)) #total words in the corpus
# Out:
# 929396

# %%
vocabs = set(words)
print(len(vocabs)) #unique words in the vocabulary
# Out:
# 23902

# %%
word_counts = Counter(words) #word_counts became integer
print(word_counts) #classification count words
# Out:
# Counter({'the': 27660, 'and': 26784, 'i': 22538, 'to': 19819, 'of': 18191, 'a': 14745, 'you': 13860, 'my': 12489, 'that': 11549, 'in': 11123, 'is': 9784, 'd': 8960, 'not': 8740, 'for': 8341, 'with': 8016, 'me': 7777, 'it': 7737, 's': 7723, 'be': 7130, 'your': 6885, 'his': 6859, 'this': 6853, 'he': 6679, 'but': 6282, 'as': 5975, 'have': 5909, 'thou': 5549, 'so': 5282, 'him': 5205, 'will': 5013, 'what': 4809, 'by': 4476, 'thy': 4034, 'all': 3965, 'are': 3894, 'her': 3850, 'do': 3834, 'no': 3803, 'we': 3624, 'shall': 3600, 'if': 3521, 'on': 3193, 'thee': 3181, 'or': 3127, 'lord': 3094, 'our': 3068, 'o': 3055, 'king': 3041, 'good': 2834, 'now': 2793, 'sir': 2764, 'from': 2654, 'they': 2531, 'at': 2524, 'come': 2519, 'she': 2410, 'll': 2409, 'let': 2369, 'enter': 2357, 'here': 2331, 'which': 2322, 'would': 2301, 'more': 2295, 'was': 2249, 'well': 2241, 'then': 2224, 'there': 2210, 'love': 2198, 'how': 2168, 'am': 2168, 'their': 2077, 'when': 2056, 'man': 2034, 'them': 1982, 'hath': 1942, 'an': 1893, 'than': 1883, 'may': 1876, 'one': 1814, 'like': 1788, 'upon': 1759, 'say': 1758, 'go': 1742, 'know': 1741, 'us': 1678, 'make': 1637, 'did': 1629, 'such': 1622, 'were': 1593, 'should': 1580, 'yet': 1577, 'must': 1492, 'why': 1476, 'see': 1462, 'had': 1428, 'out': 1415, 'tis': 1408, 'give': 1351, 'where': 1347, 'some': 1339, 'time': 1330, 'these': 1325, 'who': 1297, 'too': 1236, 'can': 1217, 't': 1213, 'take': 1212, 'speak': 1206, 'most': 1183, 'th': 1177, 'first': 1172, 'mine': 1170, 'duke': 1127, 'up': 1093, 'tell': 1083, 'father': 1076, 'think': 1074, 'st': 1065, 'heart': 1061, 'much': 1037, 'exeunt': 1035, 'never': 1020, 'exit': 984, 'queen': 979, 'nor': 971, 'men': 958, 'doth': 940, 'look': 939, 'any': 938, 'art': 936, 'day': 932, 'lady': 927, 'god': 925, 'great': 921, 'world': 905, 'death': 900, 'hear': 883, 'away': 862, 'life': 862, 'hand': 854, 'master': 844, 'before': 839, 'made': 837, 'true': 818, 'night': 816, 'very': 813, 'sweet': 807, 'scene': 799, 'thus': 782, 'own': 772, 'prince': 772, 'fair': 770, 'again': 769, 'ay': 769, 'cannot': 762, 'pray': 757, 'call': 754, 'son': 721, 'two': 714, 'old': 714, 'other': 712, 'long': 704, 'been': 698, 'eyes': 685, 'fear': 676, 'blood': 667, 'name': 666, 'being': 664, 'done': 663, 'down': 663, 'leave': 657, 'heaven': 654, 'both': 645, 'brother': 645, 'into': 644, 'nothing': 636, 'though': 634, 'honour': 632, 'poor': 631, 'could': 627, 'therefore': 627, 'er': 625, 'till': 619, 'whose': 618, 'comes': 617, 'noble': 616, 'henry': 611, 'ever': 609, 'caesar': 608, 'gloucester': 608, 'grace': 597, 'against': 595, 'better': 595, 'nay': 589, 'stand': 586, 'hast': 585, 'many': 579, 'even': 573, 'second': 572, 'house': 569, 'way': 568, 'myself': 567, 'still': 564, 'bear': 553, 'john': 551, 'use': 548, 'those': 547, 'wife': 542, 'peace': 539, 'head': 537, 'only': 533, 'dead': 533, 'find': 531, 'france': 528, 'gentleman': 523, 'antony': 520, 'richard': 520, 'live': 514, 'part': 509, 'madam': 509, 'word': 503, 'off': 501, 'might': 500, 'put': 500, 'york': 495, 'within': 494, 'show': 493, 'every': 492, 'keep': 487, 'fool': 486, 'little': 483, 'brutus': 483, 'die': 475, 'friends': 474, 'none': 469, 'hold': 468, 'young': 467, 'set': 466, 'gone': 466, 'aside': 466, 'lords': 466, 'stay': 464, 'soul': 464, 'dear': 459, 'thine': 457, 'place': 457, 'another': 455, 'mistress': 453, 'himself': 452, 'falstaff': 452, 'best': 450, 'since': 449, 'bring': 449, 'copies': 446, 'friend': 446, 'service': 444, 'electronic': 443, 'distributed': 443, 'page': 439, 'indeed': 438, 'boy': 438, 'daughter': 438, 'mother': 437, 'eye': 435, 'full': 430, 'unto': 430, 'dost': 429, 'servant': 429, 'answer': 426, 'whom': 424, 'warwick': 424, 'face': 423, 'once': 421, 'words': 421, 'others': 420, 'after': 420, 'tongue': 420, 'woman': 419, 'else': 417, 'three': 411, 'faith': 408, 'about': 403, 'please': 396, 'has': 388, 'nature': 385, 'said': 383, 'thought': 377, 'edward': 373, 'gentle': 372, 'forth': 372, 'without': 368, 'hence': 368, ' ...

# %%
print(word_counts["boy"]) #sample "boy" total words count
# Out:
# 438

# %%
print(type(word_counts))
print(type(words))
# Out:
# <class 'collections.Counter'>
# <class 'list'>

# %%
total_word_count = float(sum(word_counts.values())) #convert to float for probabilities
print(total_word_count)
# Out:
# 929396.0

# %%
word_probas = {word: word_counts[word] / total_word_count for word in word_counts.keys()} #Using Dictionary Comprehension
print(word_probas["boy"])
# Out:
# 0.0004712738165432173

# %%
def split(word):
  return [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
print(split("trash"))
# Out:
# [('', 'trash'), ('t', 'rash'), ('tr', 'ash'), ('tra', 'sh'), ('tras', 'h'), ('trash', '')]

# %%
#DELETE (remove a letter)
def delete(word):
  return [l + r[1:] for l,r in split(word) if r] 

# "l" display ['', 't', 'tr', 'tra', 'tras']
# "r[1:]" display ['rash', 'ash', 'sh', 'h', '']

# %%
print(delete("trash"))
# Out:
# ['rash', 'tash', 'trsh', 'trah', 'tras']

# %%
#SWAP (swap 2 adjacent letters)
def swap(word):
  return [l + r[1] + r[0] + r[2:] for l, r in split(word) if len(r)>1]

# %%
print(swap("trash"))
# Out:
# ['rtash', 'tarsh', 'trsah', 'trahs']

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
#REPLACE (change one letter to another)
def replace(word):
  letters = string.ascii_lowercase
  return [l + c + r[1:] for l, r in split(word) if r for c in letters]

# "l" display ['', 't', 'tr', 'tra'] over all ascii_lowercase
# "c" display all ascii_lowercase ordered
# "r[1:]" display the rest of the letter

# %%
print(replace("trash"))
# Out:
# ['arash', 'brash', 'crash', 'drash', 'erash', 'frash', 'grash', 'hrash', 'irash', 'jrash', 'krash', 'lrash', 'mrash', 'nrash', 'orash', 'prash', 'qrash', 'rrash', 'srash', 'trash', 'urash', 'vrash', 'wrash', 'xrash', 'yrash', 'zrash', 'taash', 'tbash', 'tcash', 'tdash', 'teash', 'tfash', 'tgash', 'thash', 'tiash', 'tjash', 'tkash', 'tlash', 'tmash', 'tnash', 'toash', 'tpash', 'tqash', 'trash', 'tsash', 'ttash', 'tuash', 'tvash', 'twash', 'txash', 'tyash', 'tzash', 'trash', 'trbsh', 'trcsh', 'trdsh', 'tresh', 'trfsh', 'trgsh', 'trhsh', 'trish', 'trjsh', 'trksh', 'trlsh', 'trmsh', 'trnsh', 'trosh', 'trpsh', 'trqsh', 'trrsh', 'trssh', 'trtsh', 'trush', 'trvsh', 'trwsh', 'trxsh', 'trysh', 'trzsh', 'traah', 'trabh', 'trach', 'tradh', 'traeh', 'trafh', 'tragh', 'trahh', 'traih', 'trajh', 'trakh', 'tralh', 'tramh', 'tranh', 'traoh', 'traph', 'traqh', 'trarh', 'trash', 'trath', 'trauh', 'travh', 'trawh', 'traxh', 'trayh', 'trazh', 'trasa', 'trasb', 'trasc', 'trasd', 'trase', 'trasf', 'trasg', 'trash', 'trasi', 'trasj', 'trask', 'trasl', 'trasm', 'trasn', 'traso', 'trasp', 'trasq', 'trasr', 'trass', 'trast', 'trasu', 'trasv', 'trasw', 'trasx', 'trasy', 'trasz']

# %%
#INSERT (add a letter)
def insert(word):
  letters = string.ascii_lowercase
  return [l + c + r for l, r in split(word) for c in letters]

# %%
print(insert("trash"))
# Out:
# ['atrash', 'btrash', 'ctrash', 'dtrash', 'etrash', 'ftrash', 'gtrash', 'htrash', 'itrash', 'jtrash', 'ktrash', 'ltrash', 'mtrash', 'ntrash', 'otrash', 'ptrash', 'qtrash', 'rtrash', 'strash', 'ttrash', 'utrash', 'vtrash', 'wtrash', 'xtrash', 'ytrash', 'ztrash', 'tarash', 'tbrash', 'tcrash', 'tdrash', 'terash', 'tfrash', 'tgrash', 'thrash', 'tirash', 'tjrash', 'tkrash', 'tlrash', 'tmrash', 'tnrash', 'torash', 'tprash', 'tqrash', 'trrash', 'tsrash', 'ttrash', 'turash', 'tvrash', 'twrash', 'txrash', 'tyrash', 'tzrash', 'traash', 'trbash', 'trcash', 'trdash', 'treash', 'trfash', 'trgash', 'trhash', 'triash', 'trjash', 'trkash', 'trlash', 'trmash', 'trnash', 'troash', 'trpash', 'trqash', 'trrash', 'trsash', 'trtash', 'truash', 'trvash', 'trwash', 'trxash', 'tryash', 'trzash', 'traash', 'trabsh', 'tracsh', 'tradsh', 'traesh', 'trafsh', 'tragsh', 'trahsh', 'traish', 'trajsh', 'traksh', 'tralsh', 'tramsh', 'transh', 'traosh', 'trapsh', 'traqsh', 'trarsh', 'trassh', 'tratsh', 'traush', 'travsh', 'trawsh', 'traxsh', 'traysh', 'trazsh', 'trasah', 'trasbh', 'trasch', 'trasdh', 'traseh', 'trasfh', 'trasgh', 'trashh', 'trasih', 'trasjh', 'traskh', 'traslh', 'trasmh', 'trasnh', 'trasoh', 'trasph', 'trasqh', 'trasrh', 'trassh', 'trasth', 'trasuh', 'trasvh', 'traswh', 'trasxh', 'trasyh', 'traszh', 'trasha', 'trashb', 'trashc', 'trashd', 'trashe', 'trashf', 'trashg', 'trashh', 'trashi', 'trashj', 'trashk', 'trashl', 'trashm', 'trashn', 'trasho', 'trashp', 'trashq', 'trashr', 'trashs', 'trasht', 'trashu', 'trashv', 'trashw', 'trashx', 'trashy', 'trashz']

# %%
def edit1(word):
  return set(delete(word) + swap(word) + replace(word) + insert(word))

# %%
print(edit1("trash"))
# Out:
# {'erash', 'trlsh', 'trasf', 'traso', 'otrash', 'trbash', 'trasbh', 'arash', 'trashb', 'traqsh', 'tvash', 'toash', 'trahh', 'traash', 'transh', 'mtrash', 'trapsh', 'tragsh', 'traxsh', 'htrash', 'trdsh', 'trasy', 'treash', 'trtsh', 'vrash', 'hrash', 'jrash', 'tnrash', 'trayh', 'tbrash', 'travsh', 'terash', 'trwsh', 'trysh', 'trashy', 'trakh', 'ltrash', 'qtrash', 'trach', 'tramh', 'trawh', 'tratsh', 'ntrash', 'trfash', 'prash', 'trarsh', 'atrash', 'trashj', 'tras', 'trzsh', 'tuash', 'drash', 'tgash', 'tyash', 'trasha', 'trvsh', 'trlash', 'dtrash', 'trgsh', 'trafh', 'tvrash', 'tralh', 'tragh', 'trsash', 'crash', 'trjsh', 'trxash', 'trjash', 'trasb', 'trpsh', 'tcrash', 'trtash', 'trassh', 'tranh', 'tzrash', 'grash', 'trasnh', 'trasa', 'tirash', 'trasq', 'trafsh', 'trqsh', 'tnash', 'tdrash', 'tjrash', 'ktrash', 'trish', 'trcash', 'trashi', 'tsash', 'trashk', 'tramsh', 'trasdh', 'btrash', 'traszh', 'trsah', 'itrash', 'wtrash', 'traxh', 'trasah', 'trashq', 'trashw', 'trashx', 'turash', 'trasd', 'frash', 'trzash', 'tkrash', 'jtrash', 'trkash', 'trah', 'traslh', 'mrash', 'trasih', 'trashe', 'trashu', 'xtrash', 'tcash', 'trasoh', 'tsrash', 'urash', 'trrash', 'tyrash', 'rtrash', 'ytrash', 'orash', 'trasj', 'trazsh', 'trasrh', 'lrash', 'nrash', 'trashc', 'trahs', 'tmash', 'zrash', 'ztrash', 'trgash', 'tlrash', 'trath', 'traoh', 'trasr', 'trashl', 'traskh', 'trashz', 'trqash', 'trasm', 'trarh', 'yrash', 'traesh', 'trajh', 'trashs', 'trvash', 'tiash', 'tlash', 'tfash', 'trosh', 'triash', 'trwash', 'trsh', 'trasuh', 'trashf', 'trashn', 'twash', 'tzash', 'trasc', 'trasph', 'trfsh', 'trhsh', 'trase', 'trasth', 'travh', 'traeh', 'tkash', 'xrash', 'trash', 'traph', 'trush', 'etrash', 'trhash', 'trajsh', 'ttash', 'trasxh', 'trasch', 'tradh', 'trssh', 'trnash', 'traysh', 'taash', 'traah', 'tarsh', 'trdash', 'tradsh', 'trasfh', 'trasl', 'tqrash', 'gtrash', 'tash', 'tfrash', 'trksh', 'trashd', 'trashp', 'trashv', 'rtash', 'trasvh', 'strash', 'trmash', 'trashh', 'tjash', 'traih', 'ftrash', 'trasht', 'trasn', 'trasu', 'trasz', 'brash', 'trpash', 'tpash', 'trmsh', 'trasx', 'trasho', 'trasqh', 'tgrash', 'trxsh', 'trashr', 'tralsh', 'trasv', 'traksh', 'traswh', 'trazh', 'tarash', 'traqh', 'thrash', 'rrash', 'tmrash', 'trasp', 'tdash', 'trasgh', 'troash', 'trask', 'irash', 'krash', 'trasmh', 'tracsh', 'trabsh', 'traish', 'txrash', 'ptrash', 'trauh', 'trawsh', 'trasjh', 'trasw', 'trass', 'trahsh', 'tprash', 'twrash', 'ttrash', 'utrash', 'rash', 'trasi', 'trast', 'vtrash', 'trbsh', 'ctrash', 'trasyh', 'srash', 'thash', 'trrsh', 'tresh', 'wrash', 'traush', 'trnsh', 'trashm', 'tbash', 'tqash', 'txash', 'torash', 'qrash', 'truash', 'trabh', 'teash', 'trasg', 'tryash', 'trcsh', 'trashg', 'traseh', 'traosh'}

# %%
#Performaing level_1 editing twice
def edit2(word):
  return set(e2 for e1 in edit1(word) for e2 in edit1(e1))

# %%
print(edit2("trash"))
# Out:
# {'ktrasy', 'fyash', 'traqv', 'trjfash', 'tgrksh', 'treshj', 'trahhf', 'tyaxsh', 'trasyx', 'vrashw', 'rtasc', 'traehk', 'qrass', 'trxysh', 'jtrasyh', 'tepsh', 'tsanh', 'mtrashe', 'tcrxash', 'traiswh', 'tvhsh', 'vtrawh', 'batrash', 'craesh', 'trpgash', 'zrasw', 'ftrashc', 'vtrasi', 'tryshu', 'trathf', 'trfso', 'vtraeh', 'gtwrash', 'barash', 'kqrash', 'trhxh', 'trayi', 'irasg', 'itrasm', 'sterash', 'trgmh', 'trbih', 'zrfash', 'tratjh', 'trrafh', 'pfrash', 'xtrashr', 'trcsl', 'tvish', 'dash', 'otraysh', 'rtaoh', 'trwsdh', 'twajsh', 'nrjsh', 'travshz', 'trasmha', 'trasvdh', 'trashmr', 'trisqh', 'trjacsh', 'trasxhk', 'traqsjh', 'trasqho', 'yreash', 'twrasnh', 'ntrqash', 'gtbash', 'urarh', 'trafhv', 'uraxh', 'htwrash', 'kdtrash', 'tracxsh', 'utrach', 'jjrash', 'tbrasa', 'tixash', 'trqahs', 'trastx', 'trasov', 'tdrysh', 'trbsjh', 'wurash', 'trashhy', 'htrashe', 'trqzash', 'trajv', 'utrass', 'traosch', 'gtrashn', 'trus', 'orgash', 'txasq', 'tkasht', 'transhr', 'tpramsh', 'atzrash', 'vraah', 'trrph', 'trhafh', 'troshj', 'tmasw', 'tkmash', 'wtraph', 'tryalh', 'tfrlash', 'trakwsh', 'otmash', 'rashl', 'trjsi', 'trdss', 'trhafsh', 'trds', 'tccash', 'frashn', 'gsrash', 'tnrasv', 'tralhd', 'trashfw', 'tgrasih', 'trarshm', 'strasq', 'trabl', 'trkadh', 'ktvrash', 'tkrqsh', 'qmtrash', 'tcrjsh', 'traszhg', 'wraoh', 'terush', 'treasn', 'trasnr', 'orashz', 'tcraph', 'frdash', 'urashb', 'tpprash', 'wtrsh', 'trwasn', 'truaeh', 'tgasuh', 'brasph', 'trzshw', 'tpdash', 'gtrashx', 'trpxsh', 'torasm', 'trasdth', 'traswnh', 'hrasht', 'trfashn', 'trlask', 'towsh', 'htnrash', 'ztrasha', 'trpqh', 'tjraysh', 'traup', 'rtcrash', 'rtrtash', 'ttrajh', 'tnrasw', 'tqawh', 'tmahs', 'trnsgh', 'trawhk', 'trvasw', 'traksho', 'trasyhb', 'tramh', 'trusih', 'mash', 'trnsoh', 'tzrajsh', 'trpfsh', 'raah', 'cqash', 'traisx', 'arashu', 'shrash', 'tkaseh', 'dtrqash', 'zrashk', 'itrarsh', 'ymash', 'trasthr', 'tbrapsh', 'erasyh', 'trashsz', 'tyas', 'trasap', 'orbsh', 'shash', 'trashiy', 'stravsh', 'ttasht', 'hjash', 'ktrasq', 'tpasyh', 'twxash', 'trasuih', 'traeshz', 'traskr', 'tmaso', 'trashyv', 'etrpash', 'tbrahh', 'trnasth', 'trnasih', 'otqash', 'zrasy', 'tcasih', 'trassfh', 'trvshi', 'vtrakh', 'trakv', 'txashe', 'tmurash', 'trayshl', 'tfkrash', 'tefrash', 'trashra', 'tqafsh', 'rasbh', 'trakbh', 'tjass', 'tqrasg', 'jtrwsh', 'vtrjash', 'atrasw', 'tiwrash', 'tnansh', 'rtasvh', 'tirasy', 'xrabsh', 'rkrash', 'trafse', 'attrash', 'trahmsh', 'traesvh', 'jrasfh', 'trazhv', 'hzash', 'jrasth', 'znash', 'epash', 'aytrash', 'ztrcsh', 'tuadh', 'xrdash', 'trablh', 'tsrasi', 'mrasih', 'gtrasb', 'htrzash', 'traqsha', 'traskx', 'transkh', 'btrabh', 'tofsh', 'urasd', 'qtrashz', 'taruh', 'trrasgh', 'tpasz', 'lrassh', 'trsasr', 'trrjash', 'uraszh', 'tjalsh', 'xrass', 'ttraish', 'twriash', 'jrhash', 'xtrasmh', 'twraxsh', 'trxpash', 'ktprash', 'trwasoh', 'tdasw', 'xrpsh', 'tsrasn', 'mtrach', 'trosp', 'vrbsh', 'tdvsh', 'tqasp', 'trdvsh', 'tcrashg', 'muash', 'toath', 'tfasa', 'trdavh', 'dtrfash', 'traseha', 'trjuh', 'tlrsash', 'urasha', 'trashao', 'wrsah', 'tratshp', 'tvravh', 'tioash', 'trasay', 'mtbrash', 'trnshl', 'ihrash', 'tdtsh', 'tracnsh', 'wtrasjh', 'vraslh', 'tzraseh', 'twdrash', 'tfashh', 'rotrash', 'trvsth', 'tgrashv', 'jtrasg', 'kmrash', 'tzravsh', 'wrpsh', 'traasb', 'dbash', 'tvajsh', 'traskm', 'ztrasrh', 'twach', 'ytrabh', 'trsfsh', 'utaash', 'srbash', 'tkrashe', 'tmysh', 'traslhy', 'triasg', 'trvshp', 'trabsk', 'trajhi', 'treasb', 'ttrysh', 'trasnhb', 'kmash', 'mtraish', 'tramshj', 'trasdm', 'trwask', 'gtcrash', 'ggrash', 'kresh', 'trashux', 'vrashk', 'tragb', 'trsaoh', 'tkawsh', 'tcrasx', 'trzvsh', 'traty', 'mftrash', 'trcashx', 'trazhf', 'ttrasg', 'trkast', 'orasmh', 'trhshk', 'trffh', 'tinsh', 'tryashp', 'taajh', 'traskqh', 'traqsl', 'btrish', 'tbrashg', 'teraxsh', 'trgsfh', 'trswsh', 'krazh', 'jyrash', 'trashiu', 'tmasxh', 'hrasm', 'txrpsh', 'trtasg', 'thrasgh', 'trasihn', 'tdasnh', 'thasf', 'toradh', 'trlahsh', 'trtast', 'arssh', 'tardsh', 'tralsh', 'yradsh', 'tralwsh', 'trasxr' ...

# %%
def correct_spelling(word, vocabulary, word_probabilities):
  if word in vocabulary:
    print(f"{word} is already correctly spelt")
    return 

  suggestions = edit1(word) or edit2(word) or [word]
  best_guesses = [w for w in suggestions if w in vocabulary]
  return [(w, word_probabilities[w]) for w in best_guesses]

# %%
word = "femily"
corrections = correct_spelling(word, vocabs, word_probas)

if corrections:
  print(corrections)
  probs = np.array([c[1] for c in corrections])
  best_ix = np.argmax(probs)
  correct = corrections[best_ix][0]
  print(f"{correct} is suggested for {word}")
# Out:
# [('family', 8.607740941428627e-06)]
# family is suggested for femily
